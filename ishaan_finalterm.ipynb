# %% [markdown]
# <a href="https://colab.research.google.com/github/IshaanChawla0001/python-project/blob/main/ishaan_finalterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import pandas_datareader as web

# %%
# pandas_datareader library allows us to connect to the website and extract data directly from internet sources in our case we are extracting data from Yahoo Finance API.
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2020, 1, 11)
# Read & display the data for Apple
dfa = web.DataReader("AAPL", 'yahoo', start, end)
dfa.tail(10)
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2019-12-27  73.492500  72.029999  72.779999  72.449997  146266000.0  71.246353
# 2019-12-30  73.172501  71.305000  72.364998  72.879997  144114400.0  71.669212
# 2019-12-31  73.419998  72.379997  72.482498  73.412498  100805600.0  72.192863
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.840042
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.122154
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.704819
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.358185
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.538239
# 2020-01-09  77.607498  76.550003  76.809998  77.407501  170108400.0  76.121498
# 2020-01-10  78.167503  77.062500  77.650002  77.582497  140644800.0  76.293579

# %%
# Read & display the data for Netflix
dfn = web.DataReader("NFLX", 'yahoo', start, end)
dfn.tail(10)
# Out:
#                   High         Low  ...     Volume   Adj Close
# Date                                ...
# 2019-12-27  333.820007  326.010010  ...  5036100.0  329.089996
# 2019-12-30  329.190002  322.859985  ...  4311500.0  323.309998
# 2019-12-31  324.920013  321.089996  ...  3713300.0  323.570007
# 2020-01-02  329.980011  324.779999  ...  4485800.0  329.809998
# 2020-01-03  329.859985  325.529999  ...  3806900.0  325.899994
# 2020-01-06  336.359985  321.200012  ...  5663100.0  335.829987
# 2020-01-07  336.700012  330.299988  ...  4703200.0  330.750000
# 2020-01-08  342.700012  331.049988  ...  7104500.0  339.260010
# 2020-01-09  343.420013  334.609985  ...  4709300.0  335.660004
# 2020-01-10  338.500000  327.269989  ...  4718300.0  329.049988
#
# [10 rows x 6 columns]

# %%
# Read & display the data for Microsoft
dfm = web.DataReader("MSFT", 'yahoo', start, end)
dfm.tail(10)
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2019-12-27  159.550003  158.220001  ...  18412800.0  157.293686
# 2019-12-30  159.020004  156.729996  ...  16348400.0  155.938049
# 2019-12-31  157.770004  156.449997  ...  18369400.0  156.046890
# 2020-01-02  160.729996  158.330002  ...  22622100.0  158.936279
# 2020-01-03  159.949997  158.059998  ...  21116200.0  156.957260
# 2020-01-06  159.100006  156.509995  ...  20813700.0  157.362961
# 2020-01-07  159.669998  157.320007  ...  21634100.0  155.928177
# 2020-01-08  160.800003  157.949997  ...  27746500.0  158.411835
# 2020-01-09  162.220001  161.029999  ...  21385000.0  160.390869
# 2020-01-10  163.220001  161.179993  ...  20725900.0  159.648727
#
# [10 rows x 6 columns]

# %%
# Read & display the data for Google
dfg = web.DataReader("GOOG", 'yahoo', start, end)
dfg.tail(10)
# Out:
#                    High          Low  ...     Volume    Adj Close
# Date                                  ...
# 2019-12-27  1364.530029  1349.310059  ...  1038400.0  1351.890015
# 2019-12-30  1353.000000  1334.020020  ...  1050900.0  1336.140015
# 2019-12-31  1338.000000  1329.084961  ...   961800.0  1337.020020
# 2020-01-02  1368.140015  1341.550049  ...  1406600.0  1367.369995
# 2020-01-03  1372.500000  1345.543945  ...  1186400.0  1360.660034
# 2020-01-06  1396.500000  1350.000000  ...  1732300.0  1394.209961
# 2020-01-07  1402.989990  1390.380005  ...  1502700.0  1393.339966
# 2020-01-08  1411.579956  1390.839966  ...  1528000.0  1404.319946
# 2020-01-09  1427.329956  1410.270020  ...  1500900.0  1419.829956
# 2020-01-10  1434.928955  1418.349976  ...  1820700.0  1429.729980
#
# [10 rows x 6 columns]

# %%
# Pandas reset_index() is a method to reset index of a Data Frame. reset_index() method sets a list of integer ranging from 0 to length of data as index.
dfa.reset_index(inplace=True)
dfn.reset_index(inplace=True)
dfm.reset_index(inplace=True)
dfg.reset_index(inplace=True)
dfa
# Out:
#            Date       High        Low  ...      Close       Volume  Adj Close
# 0    2010-01-04   7.660714   7.585000  ...   7.643214  493729600.0   6.539882
# 1    2010-01-05   7.699643   7.616071  ...   7.656428  601904800.0   6.551187
# 2    2010-01-06   7.686786   7.526786  ...   7.534643  552160000.0   6.446983
# 3    2010-01-07   7.571429   7.466072  ...   7.520714  477131200.0   6.435065
# 4    2010-01-08   7.571429   7.466429  ...   7.570714  447610800.0   6.477847
# ...         ...        ...        ...  ...        ...          ...        ...
# 2518 2020-01-06  74.989998  73.187500  ...  74.949997  118387200.0  73.704819
# 2519 2020-01-07  75.224998  74.370003  ...  74.597504  108872000.0  73.358185
# 2520 2020-01-08  76.110001  74.290001  ...  75.797501  132079200.0  74.538239
# 2521 2020-01-09  77.607498  76.550003  ...  77.407501  170108400.0  76.121498
# 2522 2020-01-10  78.167503  77.062500  ...  77.582497  140644800.0  76.293579
#
# [2523 rows x 7 columns]

# %%
# Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values.
dfa.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count  2523.000000  2523.000000  ...  2.523000e+03  2523.000000
# mean     27.958490    27.461572  ...  2.991392e+08    25.718650
# std      14.351418    14.123446  ...  2.351128e+08    14.377163
# min       7.000000     6.794643  ...  4.544800e+07     5.868809
# 25%      16.355000    16.055179  ...  1.246412e+08    14.058252
# 50%      25.115000    24.625000  ...  2.211236e+08    22.669634
# 75%      38.386250    37.451250  ...  4.062856e+08    36.138245
# max      78.167503    77.062500  ...  1.880998e+09    76.293579
#
# [8 rows x 6 columns]

# %%
dfn.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count  2523.000000  2523.000000  ...  2.523000e+03  2523.000000
# mean    117.959689   114.343736  ...  2.172296e+07   116.223311
# std     117.551340   114.030738  ...  2.196708e+07   115.853940
# min       7.178571     6.931428  ...  1.616300e+06     7.018571
# 25%      26.870000    25.918571  ...  8.589850e+06    26.417857
# 50%      65.142860    63.655716  ...  1.552460e+07    64.454285
# 75%     165.430000   162.755005  ...  2.706340e+07   164.139999
# max     423.209991   413.079987  ...  3.155418e+08   418.970001
#
# [8 rows x 6 columns]

# %%
dfm.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count  2523.000000  2523.000000  ...  2.523000e+03  2523.000000
# mean     57.057673    56.100781  ...  3.987757e+07    52.228972
# std      34.495816    33.961949  ...  2.297886e+07    35.232249
# min      23.320000    22.730000  ...  7.425600e+06    18.086349
# 25%      29.815000    29.224999  ...  2.424090e+07    24.167803
# 50%      45.000000    44.230000  ...  3.418460e+07    39.800991
# 75%      72.315002    71.329998  ...  4.972915e+07    68.170883
# max     163.220001   161.179993  ...  3.193179e+08   160.390869
#
# [8 rows x 6 columns]

# %%
dfg.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count  2523.000000  2523.000000  ...  2.523000e+03  2523.000000
# mean    651.321545   640.350682  ...  3.295166e+06   646.006970
# std     330.185052   324.755043  ...  2.732753e+06   327.651936
# min     220.314209   216.005356  ...  7.900000e+03   217.220810
# 25%     320.189850   314.421463  ...  1.425900e+06   317.691711
# 50%     569.925293   559.029602  ...  2.326000e+06   563.512878
# 75%     936.470001   924.515015  ...  4.437000e+06   930.549988
# max    1434.928955  1418.349976  ...  2.976060e+07  1429.729980
#
# [8 rows x 6 columns]

# %%
# Correlation is a measure of association or dependency between two features i.e. how much Y will vary with a variation in X. The correlation method that we will use is the Pearson Correlation.
corra = dfa.corr(method='pearson')
corra
# Out:
#                High       Low      Open     Close    Volume  Adj Close
# High       1.000000  0.999774  0.999856  0.999836 -0.629815   0.999123
# Low        0.999774  1.000000  0.999813  0.999844 -0.635994   0.999126
# Open       0.999856  0.999813  1.000000  0.999666 -0.632093   0.998932
# Close      0.999836  0.999844  0.999666  1.000000 -0.632978   0.999290
# Volume    -0.629815 -0.635994 -0.632093 -0.632978  1.000000  -0.631255
# Adj Close  0.999123  0.999126  0.998932  0.999290 -0.631255   1.000000

# %%
# Not all text is understandable, lets visualize the correlation coefficient.
import seaborn as sb
sb.heatmap(corr,xticklabels=corr.columns, yticklabels=corr.columns,
 cmap='RdBu_r', annot=True, linewidth=0.5)

# %%
# prepare dataset to work with 
dfa=dfa[['Date','High','Open','Low','Close']]
dfa.head(10)
# Out:
#         Date      High      Open       Low     Close
# 0 2010-01-04  7.660714  7.622500  7.585000  7.643214
# 1 2010-01-05  7.699643  7.664286  7.616071  7.656428
# 2 2010-01-06  7.686786  7.656428  7.526786  7.534643
# 3 2010-01-07  7.571429  7.562500  7.466072  7.520714
# 4 2010-01-08  7.571429  7.510714  7.466429  7.570714
# 5 2010-01-11  7.607143  7.600000  7.444643  7.503929
# 6 2010-01-12  7.491786  7.471071  7.372143  7.418571
# 7 2010-01-13  7.533214  7.423929  7.289286  7.523214
# 8 2010-01-14  7.516428  7.503929  7.465000  7.479643
# 9 2010-01-15  7.557143  7.533214  7.352500  7.354643

# %%
plt.figure(figsize=(16,8))
plt.title('Apple Stocks Closing Price History 2010-2020')
plt.plot(dfa['Date'],dfa['Close'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price US($)',fontsize=18)
plt.style.use('fivethirtyeight')
plt.show()

# %%
# Plot Open vs Close
dfa[['Open','Close']].head(20).plot(kind='bar',figsize=(16,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
#Plot High vs Close
dfa[['High','Close']].head(20).plot(kind='bar',figsize=(16,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# # **Model Training and Testing**

# %%
# Date format is DateTime and it will throw error while training so I have created seperate month, year and date entities
# Apple 
dfa['Year']=dfa['Date'].dt.year
dfa['Month']=dfa['Date'].dt.year
dfa['Day']=dfa['Date'].dt.year
dfa['Year']
# Out:
# 0       2010
# 1       2010
# 2       2010
# 3       2010
# 4       2010
#         ...
# 2518    2020
# 2519    2020
# 2520    2020
# 2521    2020
# 2522    2020
# Name: Year, Length: 2523, dtype: int64

# %%
# Netflix 
dfn['Year']=dfn['Date'].dt.year
dfn['Month']=dfn['Date'].dt.year
dfn['Day']=dfn['Date'].dt.year
# Microsoft 
dfm['Year']=dfm['Date'].dt.year
dfm['Month']=dfm['Date'].dt.year
dfm['Day']=dfm['Date'].dt.year
# Google 
dfg['Year']=dfg['Date'].dt.year
dfg['Month']=dfg['Date'].dt.year
dfg['Day']=dfg['Date'].dt.year

# %% [markdown]
# # **Create the final dataset for Model training**

# %%
aapl_df=dfa[['Day','Month','Year','High','Open','Low','Close']]
aapl_df.head(10)
# Out:
#     Day  Month  Year      High      Open       Low     Close
# 0  2010   2010  2010  7.660714  7.622500  7.585000  7.643214
# 1  2010   2010  2010  7.699643  7.664286  7.616071  7.656428
# 2  2010   2010  2010  7.686786  7.656428  7.526786  7.534643
# 3  2010   2010  2010  7.571429  7.562500  7.466072  7.520714
# 4  2010   2010  2010  7.571429  7.510714  7.466429  7.570714
# 5  2010   2010  2010  7.607143  7.600000  7.444643  7.503929
# 6  2010   2010  2010  7.491786  7.471071  7.372143  7.418571
# 7  2010   2010  2010  7.533214  7.423929  7.289286  7.523214
# 8  2010   2010  2010  7.516428  7.503929  7.465000  7.479643
# 9  2010   2010  2010  7.557143  7.533214  7.352500  7.354643

# %%
# for other stocks
nflx_df=dfa[['Day','Month','Year','High','Open','Low','Close']]
nflx_df.head(10)
msft_df=dfa[['Day','Month','Year','High','Open','Low','Close']]
msft_df.head(10)
goog_df=dfa[['Day','Month','Year','High','Open','Low','Close']]
goog_df.head(10)
# Out:
#     Day  Month  Year      High      Open       Low     Close
# 0  2010   2010  2010  7.660714  7.622500  7.585000  7.643214
# 1  2010   2010  2010  7.699643  7.664286  7.616071  7.656428
# 2  2010   2010  2010  7.686786  7.656428  7.526786  7.534643
# 3  2010   2010  2010  7.571429  7.562500  7.466072  7.520714
# 4  2010   2010  2010  7.571429  7.510714  7.466429  7.570714
# 5  2010   2010  2010  7.607143  7.600000  7.444643  7.503929
# 6  2010   2010  2010  7.491786  7.471071  7.372143  7.418571
# 7  2010   2010  2010  7.533214  7.423929  7.289286  7.523214
# 8  2010   2010  2010  7.516428  7.503929  7.465000  7.479643
# 9  2010   2010  2010  7.557143  7.533214  7.352500  7.354643

# %%
#separate Independent and dependent variable
X = aapl_df.iloc[:,aapl_df.columns !='Close']
Y= aapl_df.iloc[:, 5]
print(X.shape)
print(Y.shape)
# Out:
# (2523, 6)
# (2523,)

# %% [markdown]
# # **Splitting the dataset into train and test**

# %%
x_train,x_test,y_train,y_test= train_test_split(X,Y,test_size=.25)

# %%
print(x_train.shape) 
print(x_test.shape)  
print(y_train.shape)
print(y_test.shape) 
#y_test to be evaluated with y_pred for Diff models
# Out:
# (1892, 6)
# (631, 6)
# (1892,)
# (631,)

# %% [markdown]
# # **Linear Regression Model Training and Testing**

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
y_pred=regressor.predict(x_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#          Actual  Predicted
# 1364  32.422501  32.422501
# 2277  39.182499  39.182499
# 1930  41.235001  41.235001
# 1701  28.415001  28.415001
# 462   14.267858  14.267858
# ...         ...        ...
# 1039  19.178572  19.178572
# 2044  43.272499  43.272499
# 866   15.612143  15.612143
# 2460  59.410000  59.410000
# 80     9.642858   9.642858
#
# [631 rows x 2 columns]

# %%
plot_df=pd.DataFrame({'Actual':y_test,'Pred':y_pred})
plot_df.head(20).plot(kind='bar',figsize=(16,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test,y_pred))
# Out:
# Mean squared error: 0.00

# %%
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test,y_pred))
# Out:
# Coefficient of determination: 1.00
