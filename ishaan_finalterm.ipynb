# %% [markdown]
# <a href="https://colab.research.google.com/github/IshaanChawla0001/python-project/blob/main/ishaan_finalterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import pandas_datareader as web

# %%
# pandas_datareader library allows us to connect to the website and extract data directly from internet sources in our case we are extracting data from Yahoo Finance API.
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2019, 1, 11)
# Read & display the data for Apple
dfa = web.DataReader("AAPL", 'yahoo', start, end)
dfa.tail(10)
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2018-12-28  39.630001  38.637501  39.375000  39.057499  169165600.0  37.840069
# 2018-12-31  39.840000  39.119999  39.632500  39.435001  140014000.0  38.205803
# 2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0  38.249401
# 2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0  34.439476
# 2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0  35.909672
# 2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0  35.829746
# 2019-01-08  37.955002  37.130001  37.389999  37.687500  164101200.0  36.512772
# 2019-01-09  38.632500  37.407501  37.822498  38.327499  180396400.0  37.132820
# 2019-01-10  38.492500  37.715000  38.125000  38.450001  143122800.0  37.251511
# 2019-01-11  38.424999  37.877499  38.220001  38.072498  108092800.0  36.885773

# %%
# Read & display the data for Netflix
dfn = web.DataReader("NFLX", 'yahoo', start, end)
dfn.tail(10)
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2018-12-28  261.910004  249.800003  ...  10992800.0  256.079987
# 2018-12-31  270.100006  260.000000  ...  13508900.0  267.660004
# 2019-01-02  269.750000  256.579987  ...  11679500.0  267.660004
# 2019-01-03  275.790009  264.429993  ...  14969600.0  271.200012
# 2019-01-04  297.799988  278.540009  ...  19330100.0  297.570007
# 2019-01-07  316.799988  301.649994  ...  18620100.0  315.339996
# 2019-01-08  320.589996  308.010010  ...  15359200.0  320.269989
# 2019-01-09  323.350006  313.500000  ...  13343200.0  319.959991
# 2019-01-10  325.369995  312.500000  ...  13472500.0  324.660004
# 2019-01-11  341.089996  328.519989  ...  19500400.0  337.589996
#
# [10 rows x 6 columns]

# %%
# Read & display the data for Microsoft
dfm = web.DataReader("MSFT", 'yahoo', start, end)
dfm.tail(10)
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2018-12-28  102.410004   99.519997  ...  38196300.0   97.890251
# 2018-12-31  102.400002  100.440002  ...  33173800.0   99.040863
# 2019-01-02  101.750000   98.940002  ...  35329300.0   98.602066
# 2019-01-03  100.190002   97.199997  ...  42579100.0   94.974693
# 2019-01-04  102.510002   98.930000  ...  44060600.0   99.391899
# 2019-01-07  103.269997  100.980003  ...  35656100.0   99.518669
# 2019-01-08  103.970001  101.709999  ...  31514400.0  100.240234
# 2019-01-09  104.879997  103.239998  ...  32280800.0  101.673622
# 2019-01-10  103.750000  102.379997  ...  30067600.0  101.020325
# 2019-01-11  103.440002  101.639999  ...  28314200.0  100.240234
#
# [10 rows x 6 columns]

# %%
# Read & display the data for Google
dfg = web.DataReader("GOOG", 'yahoo', start, end)
dfg.tail(10)
# Out:
#                    High          Low  ...     Volume    Adj Close
# Date                                  ...
# 2018-12-28  1055.560059  1033.099976  ...  1414800.0  1037.079956
# 2018-12-31  1052.699951  1023.590027  ...  1493300.0  1035.609985
# 2019-01-02  1052.319946  1015.710022  ...  1532600.0  1045.849976
# 2019-01-03  1056.979980  1014.070007  ...  1841100.0  1016.059998
# 2019-01-04  1070.839966  1027.417969  ...  2093900.0  1070.709961
# 2019-01-07  1074.000000  1054.760010  ...  1981900.0  1068.390015
# 2019-01-08  1084.560059  1060.530029  ...  1764900.0  1076.280029
# 2019-01-09  1082.630005  1066.400024  ...  1199300.0  1074.660034
# 2019-01-10  1071.150024  1057.709961  ...  1456400.0  1070.329956
# 2019-01-11  1063.775024  1048.479980  ...  1520800.0  1057.189941
#
# [10 rows x 6 columns]

# %%
# Pandas reset_index() is a method to reset index of a Data Frame. reset_index() method sets a list of integer ranging from 0 to length of data as index.
dfa.reset_index(inplace=True)
dfn.reset_index(inplace=True)
dfm.reset_index(inplace=True)
dfg.reset_index(inplace=True)
dfa
# Out:
#       index       Date       High  ...      Close       Volume  Adj Close
# 0         0 2010-01-04   7.660714  ...   7.643214  493729600.0   6.539882
# 1         1 2010-01-05   7.699643  ...   7.656428  601904800.0   6.551187
# 2         2 2010-01-06   7.686786  ...   7.534643  552160000.0   6.446983
# 3         3 2010-01-07   7.571429  ...   7.520714  477131200.0   6.435065
# 4         4 2010-01-08   7.571429  ...   7.570714  447610800.0   6.477847
# ...     ...        ...        ...  ...        ...          ...        ...
# 2267   2267 2019-01-07  37.207500  ...  36.982498  219111200.0  35.829746
# 2268   2268 2019-01-08  37.955002  ...  37.687500  164101200.0  36.512772
# 2269   2269 2019-01-09  38.632500  ...  38.327499  180396400.0  37.132820
# 2270   2270 2019-01-10  38.492500  ...  38.450001  143122800.0  37.251511
# 2271   2271 2019-01-11  38.424999  ...  38.072498  108092800.0  36.885773
#
# [2272 rows x 8 columns]

# %%
# Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values.
dfa.describe()
# Out:
#              index         High  ...        Volume    Adj Close
# count  2272.000000  2272.000000  ...  2.272000e+03  2272.000000
# mean   1135.500000    25.128288  ...  3.200194e+08    22.814269
# std     656.014227    11.794846  ...  2.384068e+08    11.644931
# min       0.000000     7.000000  ...  4.590360e+07     5.868809
# 25%     567.750000    15.576518  ...  1.377401e+08    13.407786
# 50%    1135.500000    23.922500  ...  2.526902e+08    21.250891
# 75%    1703.250000    31.798750  ...  4.305168e+08    28.670048
# max    2271.000000    58.367500  ...  1.880998e+09    56.013641
#
# [8 rows x 7 columns]

# %%
dfn.describe()
# Out:
#              index         High  ...        Volume    Adj Close
# count  2272.000000  2272.000000  ...  2.272000e+03  2272.000000
# mean   1135.500000    94.106358  ...  2.329135e+07    92.642414
# std     656.014227    97.440891  ...  2.256073e+07    95.843593
# min       0.000000     7.178571  ...  1.616300e+06     7.018571
# 25%     567.750000    24.990000  ...  9.900000e+06    24.369642
# 50%    1135.500000    58.225714  ...  1.740325e+07    57.771427
# 75%    1703.250000   123.332502  ...  2.883212e+07   122.037498
# max    2271.000000   423.209991  ...  3.155418e+08   418.970001
#
# [8 rows x 7 columns]

# %%
dfm.describe()
# Out:
#              index         High  ...        Volume    Adj Close
# count  2272.000000  2272.000000  ...  2.272000e+03  2272.000000
# mean   1135.500000    48.672702  ...  4.161091e+07    43.644413
# std     656.014227    24.295474  ...  2.345384e+07    24.748456
# min       0.000000    23.320000  ...  7.425600e+06    18.086349
# 25%     567.750000    29.207500  ...  2.588312e+07    23.582325
# 50%    1135.500000    41.775000  ...  3.617245e+07    36.654112
# 75%    1703.250000    58.194999  ...  5.168290e+07    53.911827
# max    2271.000000   116.180000  ...  3.193179e+08   112.246353
#
# [8 rows x 7 columns]

# %%
dfg.describe()
# Out:
#              index         High  ...        Volume    Adj Close
# count  2272.000000  2272.000000  ...  2.272000e+03  2272.000000
# mean   1135.500000   589.980664  ...  3.503551e+06   584.995838
# std     656.014227   287.128139  ...  2.795384e+06   284.579552
# min       0.000000   220.314209  ...  7.900000e+03   217.220810
# 25%     567.750000   310.834900  ...  1.527850e+06   308.039131
# 50%    1135.500000   541.177063  ...  2.668350e+06   537.816772
# 75%    1703.250000   780.562485  ...  4.652150e+06   775.345001
# max    2271.000000  1273.890015  ...  2.976060e+07  1268.329956
#
# [8 rows x 7 columns]

# %%
# Correlation is a measure of association or dependency between two features i.e. how much Y will vary with a variation in X. The correlation method that we will use is the Pearson Correlation.
# Apple stock
corr = dfa.corr(method='pearson')
corr
# Out:
#               index      High       Low  ...     Close    Volume  Adj Close
# index      1.000000  0.928554  0.928947  ...  0.928765 -0.719644   0.931925
# High       0.928554  1.000000  0.999706  ...  0.999793 -0.627565   0.998878
# Low        0.928947  0.999706  1.000000  ...  0.999804 -0.635694   0.998875
# Open       0.928455  0.999818  0.999757  ...  0.999573 -0.630317   0.998641
# Close      0.928765  0.999793  0.999804  ...  1.000000 -0.631980   0.999073
# Volume    -0.719644 -0.627565 -0.635694  ... -0.631980  1.000000  -0.633172
# Adj Close  0.931925  0.998878  0.998875  ...  0.999073 -0.633172   1.000000
#
# [7 rows x 7 columns]

# %%
# Not all text is understandable, lets visualize the correlation coefficient.
import seaborn as sb
sb.heatmap(corr,xticklabels=corr.columns, yticklabels=corr.columns,
 cmap='RdBu_r', annot=True, linewidth=0.5)

# %%
# prepare dataset to work with 
dfa=dfa[['Date','High','Open','Low','Close']]
dfa.head(10)
# Out:
#         Date      High      Open       Low     Close
# 0 2010-01-04  7.660714  7.622500  7.585000  7.643214
# 1 2010-01-05  7.699643  7.664286  7.616071  7.656428
# 2 2010-01-06  7.686786  7.656428  7.526786  7.534643
# 3 2010-01-07  7.571429  7.562500  7.466072  7.520714
# 4 2010-01-08  7.571429  7.510714  7.466429  7.570714
# 5 2010-01-11  7.607143  7.600000  7.444643  7.503929
# 6 2010-01-12  7.491786  7.471071  7.372143  7.418571
# 7 2010-01-13  7.533214  7.423929  7.289286  7.523214
# 8 2010-01-14  7.516428  7.503929  7.465000  7.479643
# 9 2010-01-15  7.557143  7.533214  7.352500  7.354643
